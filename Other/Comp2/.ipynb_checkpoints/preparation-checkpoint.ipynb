# %%
import pandas as pd

# %%
df = pd.read_csv("main.csv", index_col=0)

# %%
df.head()
# Out:
#   Раздел                                              Слова Важность  \
# 0    NaN                                                NaN      NaN
# 1      1                                  Организация работ        5
# 2    NaN  Специалист должен знать и понимать: \n  Закон...      NaN
# 3    NaN  Специалист должен уметь: \n  Следовать правил...      NaN
# 4    NaN    Проявлять энтузиазм в апробации новых метод...      NaN
#
#                              Компетенция  \
# 0  Информационные кабельные сети(юниоры)
# 1  Информационные кабельные сети(юниоры)
# 2  Информационные кабельные сети(юниоры)
# 3  Информационные кабельные сети(юниоры)
# 4  Информационные кабельные сети(юниоры)
#
#                                            Блок
# 0  Информационные и коммуникационные технологии
# 1  Информационные и коммуникационные технологии
# 2  Информационные и коммуникационные технологии
# 3  Информационные и коммуникационные технологии
# 4  Информационные и коммуникационные технологии

# %%
df = df.drop(["Раздел", "Важность"], axis=1)

# %%
df = df.dropna()

# %%
df = df[df["Слова"] != 'Всего']

# %%
print(df["Слова"][2583])
# Out:
#   контролировать наличие посторонних предметов (камней,

# %%
df
# Out:
#                                                   Слова  \
# 1                                     Организация работ
# 2     Специалист должен знать и понимать: \n  Закон...
# 3     Специалист должен уметь: \n  Следовать правил...
# 4       Проявлять энтузиазм в апробации новых метод...
# 5                                Коммуникативные навыки
# ...                                                 ...
# 2582  при работе на фронтальном погрузчике и в движе...
# 2583    контролировать наличие посторонних предмето...
# 2584  пней),ограждений и предупредительных знаков в ...
# 2585    выявлять,  устранять  и  предотвращать  при...
# 2586               нарушений технологического процесса.
#
#                                 Компетенция  \
# 1     Информационные кабельные сети(юниоры)
# 2     Информационные кабельные сети(юниоры)
# 3     Информационные кабельные сети(юниоры)
# 4     Информационные кабельные сети(юниоры)
# 5     Информационные кабельные сети(юниоры)
# ...
