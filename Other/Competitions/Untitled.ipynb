# %%
import pandas as pd

# %%
df = pd.read_csv("clear_data.csv")

# %%
df
# Out:
#      Unnamed: 0  CIS  Тип                        Название компетенции  \
# 0             1  E57  WSE                     Администрирование отеля
# 1             3    8  WSI               Архитектурная обработка камня
# 2             6   17  WSI                     Веб-дизайн и разработка
# 3             7  R56   RU                                 Ветеринария
# 4             8   R1   RU                           Видеопроизводство
# ..          ...  ...  ...                                         ...
# 176           9  T32   RU                           Цифровой модельер
# 177          10   T5   RU  Эксплуатация грузового речного\rтранспорта
# 178          11  T75   RU              Эксплуатация сервисных роботов
# 179          12  R61   RU                    Электрослесарь подземный
# 180          13  T80   RU                     Технология энергоаудита
#
#                        Name of competence              Статус компетенции  \
# ...

# %%
# Out:
#        Unnamed: 0
# count  181.000000
# mean     9.215470
# std      5.749684
# min      0.000000
# 25%      4.000000
# 50%      9.000000
# 75%     14.000000
# max     24.000000
